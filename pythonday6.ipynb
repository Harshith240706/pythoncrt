# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshith240706/pythoncrt/blob/main/pythonday6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x="AAACCDDDAAD"
res=""
c=1
for i in range(len(x)):
  if  i+1 < len(x) and x[i]==x[i+1]:
    c=c+1
  else:
      res=res+x[i]
      res=res+str(c)
      c=1
print(res)
# Out:
# A3C2D3A2D1

# %%
def flower(a):
  if a == 4:
    return

  print(a + 10, end=" ")
  flower(a + 1)
  print(a, end=" ")
flower(1)
# Out:
# 11 12 13 3 2 1

# %%
def raju(a):
  if a==1:
    return
  a-=1
  raju(a)
  print("Hai")
  raju(a)
raju(5)
# Out:
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai

# %%
def raju(a):
  if a == 4:
    return 1

  B=raju(a+1)
  print("Hai")
  return B+2

res=raju(1)
print(res)
# Out:
# Hai
# Hai
# Hai
# 7

# %%
import qrcode
qr=qrcode.QRCode()
a="TVK is rocking"
qr.add_data(a)
qr make
